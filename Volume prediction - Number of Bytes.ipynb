# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Flatten, Bidirectional, GRU, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.callbacks import EarlyStopping
from keras.layers import ConvLSTM2D

# %%
result_df = pd.read_csv("./Windowed Data.csv")
result_df = result_df.drop(labels=["Unnamed: 0"],axis=1)

# %%
result_df
# Out:
#          Time  Total.Fwd.Packets  Total.Backward.Packets  \
# 0    03:03:25             321673                  378953
# 1    03:03:30              71333                   86846
# 2    03:03:35              49026                   65682
# 3    03:03:40              29460                   39111
# 4    03:03:45              27611                   31320
# ..        ...                ...                     ...
# 689  11:40:54                 78                      52
# 690  11:41:00                 73                      51
# 691  11:41:06               5862                    4162
# 692  11:41:12               1569                     596
# 693  11:41:17                 16                       4
#
#      Total.Length.of.Fwd.Packets  Total.Length.of.Bwd.Packets  \
# 0                      176001042                    688917718
# 1                        9552175                    184810368
# 2                        2439004                    142056259
# 3                        3986939                     59917713
# 4                        4254925                     34013794
# ..                           ...                          ...
# 689                         6499                        50290
# 690                         7804                        34860
# 691                      4156420                      1072047
# 692                      1863989                       418451
# 693                         2341                          276
#
#      Total.Num.Packets  Total.bytes.of.Packets
# 0               700626               864918760
# 1               158179               194362543
# 2               114708               144495263
# 3                68571                63904652
# 4                58931                38268719
# ..                 ...                     ...
# 689                130                   56789
# 690                124                   42664
# 691              10024                 5228467
# 692               2165                 2282440
# 693                 20                    2617
#
# [694 rows x 7 columns]

# %%
def timeseries (x_axis, y_axis, x_label, y_label):
    plt.figure(figsize = (15,10))
    plt.plot(x_axis, y_axis, color ='black')
    plt.xlabel(x_label, {'fontsize': 12}) 
    plt.ylabel(y_label, {'fontsize': 12})
    #plt.xticks(range(0,df.shape[0],500),df['Date'].loc[::500],rotation=45)
timeseries(result_df["Time"].astype("str"), result_df['Total.Num.Packets'], 'Time','Total Number of Packets')

# %%
timeseries(result_df["Time"].astype("str"), result_df['Total.bytes.of.Packets'], 'Time','Total Bytes of Packets')

# %%
def timeseries (x_axis, y_axis, x_label, y_label):
    plt.figure(figsize = (10, 6))
    x_list=[]
    y_list=[]
    for i in range(0,len(y_axis),75):
      x_list.append(x_axis[i])
      y_list.append(y_axis[i])
    plt.plot(x_list, y_list, color ='black')
    plt.xlabel(x_label, {'fontsize': 12}) 
    plt.ylabel(y_label, {'fontsize': 12})
timeseries(result_df["Time"].astype("str"), result_df['Total.Num.Packets'], 'Time','Total Number of Packets')

# %%
timeseries(result_df["Time"].astype("str"), result_df['Total.bytes.of.Packets'], 'Time','Total Bytes of Packets')

# %%
train_size = int(len(result_df)*0.8)
train_dataset, test_dataset = result_df.iloc[:train_size],result_df.iloc[train_size:]
train_dataset = train_dataset.reset_index(drop=True)
test_dataset = test_dataset.reset_index(drop=True)

# %%
train_dataset.head()
# Out:
#        Time  Total.Fwd.Packets  Total.Backward.Packets  \
# 0  03:03:25             321673                  378953
# 1  03:03:30              71333                   86846
# 2  03:03:35              49026                   65682
# 3  03:03:40              29460                   39111
# 4  03:03:45              27611                   31320
#
#    Total.Length.of.Fwd.Packets  Total.Length.of.Bwd.Packets  \
# 0                    176001042                    688917718
# 1                      9552175                    184810368
# 2                      2439004                    142056259
# 3                      3986939                     59917713
# 4                      4254925                     34013794
#
#    Total.Num.Packets  Total.bytes.of.Packets
# 0             700626               864918760
# 1             158179               194362543
# 2             114708               144495263
# 3              68571                63904652
# 4              58931                38268719

# %%
test_dataset.head()
# Out:
#        Time  Total.Fwd.Packets  Total.Backward.Packets  \
# 0  11:29:20               2343                    1407
# 1  11:29:25               8579                    1472
# 2  11:29:30                563                     584
# 3  11:29:35                416                     428
# 4  11:29:41                422                     431
#
#    Total.Length.of.Fwd.Packets  Total.Length.of.Bwd.Packets  \
# 0                      1837286                       319237
# 1                     12291419                       511406
# 2                        72902                        72900
# 3                        64651                       143964
# 4                       103714                       125424
#
#    Total.Num.Packets  Total.bytes.of.Packets
# 0               3750                 2156523
# 1              10051                12802825
# 2               1147                  145802
# 3                844                  208615
# 4                853                  229138

# %%
plt.figure(figsize = (15,10))
plt.plot(train_dataset["Time"],train_dataset["Total.Num.Packets"])
plt.plot(test_dataset["Time"],test_dataset["Total.Num.Packets"])
plt.xlabel('Time')
plt.ylabel('Total Number of Packets')
plt.legend(['Train set', 'Test set'], loc='upper right')

# %%
plt.figure(figsize = (15,10))
plt.plot(train_dataset["Time"],train_dataset["Total.bytes.of.Packets"])
plt.plot(test_dataset["Time"],test_dataset["Total.bytes.of.Packets"])
plt.xlabel('Time')
plt.ylabel('Total Number of Packets')
plt.legend(['Train set', 'Test set'], loc='upper right')

# %%
X_train = train_dataset[["Total.Fwd.Packets","Total.Backward.Packets","Total.Num.Packets"]]
y_train = train_dataset["Total.bytes.of.Packets"]
X_test = test_dataset[["Total.Fwd.Packets","Total.Backward.Packets","Total.Num.Packets"]]
y_test = test_dataset["Total.bytes.of.Packets"]

# %%
# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)

output_scaler = scaler_y.fit(y_train.values.reshape(-1,1))
# Apply the scaler to training data
train_x_norm = input_scaler.transform(X_train)
train_y_norm = output_scaler.transform(y_train.values.reshape(-1,1))
# Apply the scaler to test data

test_x_norm = input_scaler.transform(X_test)
test_y_norm = output_scaler.transform(y_test.values.reshape(-1,1))

# %%
X_train[0:30]
# Out:
#     Total.Fwd.Packets  Total.Backward.Packets  Total.Num.Packets
# 0              321673                  378953             700626
# 1               71333                   86846             158179
# 2               49026                   65682             114708
# 3               29460                   39111              68571
# 4               27611                   31320              58931
# 5               26364                   31688              58052
# 6               15644                   17490              33134
# 7               81070                   90771             171841
# 8               19720                   23998              43718
# 9               33812                   41075              74887
# 10              51483                   61754             113237
# 11              46683                   51890              98573
# 12              64865                   70520             135385
# 13             114741                  129773             244514
# 14              60494                   69971             130465
# 15              49731                   58038             107769
# 16              33540                   33957              67497
# 17              30708                   33293              64001
# 18              42258                   53751              96009
# 19              17473                   20470              37943
# 20              28567                   33719              62286
# 21              25398                   40860              66258
# 22              18111                   26425              44536
# 23              44178                   59483             103661
# 24             204065                  226945             431010
# 25              46322                   59028             105350
# 26              39552                   48538              88090
# 27              43692                   53976              97668
# 28              41985                   53977              95962
# 29              31979                   43395              75374

# %%
def create_dataset (X, y, time_steps = 1):
    Xs, ys = [], []
    for i in range(len(X)-time_steps):
        v = X[i:i+time_steps]
        Xs.append(v)
        ys.append(y[i+time_steps])
    return np.array(Xs), np.array(ys)
TIME_STEPS = 30

X_train, y_train = create_dataset(train_x_norm, train_y_norm, TIME_STEPS)
y_train = y_train.reshape(-1,1)
print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
# Out:
# X_train.shape:  (525, 30, 3)
# y_train.shape:  (525, 1)

# %%
X_test, y_test = create_dataset(test_x_norm, test_y_norm,TIME_STEPS)
y_test = y_test.reshape(-1,1)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_test.shape)
# Out:
# X_test.shape:  (109, 30, 3)
# y_test.shape:  (109, 1)

# %%
X_train.shape[1]
# Out:
# 30

# %%
from tensorflow import keras

# %%
# Create BiLSTM model
def create_model_bilstm(units):
    model = Sequential()
    model.add(Bidirectional(LSTM(units = units,                             
              return_sequences=True),
              input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Bidirectional(LSTM(units = units)))
    model.add(Dense(1))
    #Compile model
    model.compile(loss='mse', optimizer='adam')
    return model
# Create LSTM or GRU model
def create_model(units, m):
    model = Sequential()
    model.add(m (units = units, return_sequences = True,
                input_shape = (X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(0.2))
    model.add(m (units = units))
    model.add(Dropout(0.2))
    model.add(Dense(units = 1))
    #Compile model
    model.compile(loss='mse', optimizer='adam')
    return model
# BiLSTM
model_bilstm = create_model_bilstm(64)
# GRU and LSTM
model_gru = create_model(64, GRU)
model_lstm = create_model(64, LSTM)

# %%
# Fit BiLSTM, LSTM and GRU
def fit_model(model):
    early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',
                                               patience = 10)
    history = model.fit(X_train, y_train, epochs = 100,  
                        validation_split = 0.2, batch_size = 32, 
                        shuffle = False, callbacks = [early_stop])
    return history
history_bilstm = fit_model(model_bilstm)
history_lstm = fit_model(model_lstm)
history_gru = fit_model(model_gru)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 5s 86ms/step - loss: 0.0066 - val_loss: 0.0011
# Epoch 2/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0052 - val_loss: 7.2963e-04
# Epoch 3/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 8.7010e-04
# Epoch 4/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 7.7933e-04
# Epoch 5/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0047 - val_loss: 7.5827e-04
# Epoch 6/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0047 - val_loss: 7.9842e-04
# Epoch 7/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0047 - val_loss: 7.6750e-04
# Epoch 8/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0047 - val_loss: 7.6795e-04
# Epoch 9/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0047 - val_loss: 7.8968e-04
# Epoch 10/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0047 - val_loss: 7.6848e-04
# Epoch 11/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0047 - val_loss: 7.7331e-04
# Epoch 12/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0047 - val_loss: 7.8595e-04
# Epoch 1/100
# 14/14 [==============================] - 2s 37ms/step - loss: 0.0065 - val_loss: 7.5518e-04
# Epoch 2/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0051 - val_loss: 8.3873e-04
# Epoch 3/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0050 - val_loss: 7.9719e-04
# Epoch 4/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 8.2024e-04
# Epoch 5/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 8.4476e-04
# Epoch 6/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 7.7789e-04
# Epoch 7/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 8.2728e-04
# Epoch 8/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 8.3183e-04
# Epoch 9/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 7.7888e-04
# Epoch 10/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 7.8915e-04
# Epoch 11/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 8.1735e-04
# Epoch 1/100
# 14/14 [==============================] - 2s 32ms/step - loss: 0.0061 - val_loss: 0.0021
# Epoch 2/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 7.7264e-04
# Epoch 3/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 8.4846e-04
# Epoch 4/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 9.4444e-04
# Epoch 5/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 7.4790e-04
# Epoch 6/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 8.0437e-04
# Epoch 7/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 8.6159e-04
# Epoch 8/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 8.7509e-04
# Epoch 9/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 8.0880e-04
# Epoch 10/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 7.7666e-04
# Epoch 11/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 8.4209e-04
# Epoch 12/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 8.4687e-04
# Epoch 13/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 8.3955e-04
# Epoch 14/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 7.6237e-04
# Epoch 15/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 8.2520e-04

# %%
def plot_loss (history,title=""):
    plt.figure(figsize = (10, 6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')
    plt.title(title)
plot_loss (history_bilstm,"Bidirectional LSTM")
plot_loss (history_lstm,"LSTM")
plot_loss (history_gru,"GRU")

# %%
# y_test = scaler_y.inverse_transform(y_test)
# y_train = scaler_y.inverse_transform(y_train)

# %%
# Make prediction
def prediction(model):
    prediction = model.predict(X_test)
    #prediction = scaler_y.inverse_transform(prediction)
    return prediction

# %%
prediction_bilstm = prediction(model_bilstm)
prediction_lstm = prediction(model_lstm)
prediction_gru = prediction(model_gru)

# %%
# Plot true future vs prediction
def plot_future(prediction, y_test,title=""):
    plt.figure(figsize=(10, 6))
    range_future = len(prediction)
    plt.plot(np.arange(range_future), np.array(y_test), 
             label='True Future')     
    plt.plot(np.arange(range_future),np.array(prediction),
            label='Prediction')
    plt.legend(loc='upper left')
    plt.xlabel('Time')
    plt.ylabel('Total Bytes of Packets')
    plt.title(title)
plot_future(prediction_bilstm, y_test,"Bidirectional LSTM")
plot_future(prediction_lstm, y_test,"LSTM")
plot_future(prediction_gru, y_test,"GRU")

# %%
# Define a function to calculate MAE and RMSE
def evaluate_prediction(predictions, actual, model_name):
    errors = predictions - actual
    mse = np.square(errors).mean()
    rmse = np.sqrt(mse)
    mae = np.abs(errors).mean()
    print(model_name + ':')
    print('Mean Absolute Error: {:.4f}'.format(mae))
    print('Root Mean Square Error: {:.4f}'.format(rmse))
    print('')
evaluate_prediction(prediction_bilstm, y_test, 'Bidirectional LSTM')
evaluate_prediction(prediction_lstm, y_test, 'LSTM')
evaluate_prediction(prediction_gru, y_test, 'GRU')
# Out:
# Bidirectional LSTM:
# Mean Absolute Error: 0.0121
# Root Mean Square Error: 0.0143
#
# LSTM:
# Mean Absolute Error: 0.0134
# Root Mean Square Error: 0.0152
#
# GRU:
# Mean Absolute Error: 0.0130
# Root Mean Square Error: 0.0153
